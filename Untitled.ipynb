# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import warnings

from sklearn.pipeline import Pipeline

warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\moham\Desktop\thesis\thesis\data\data.csv').drop(['name', 'year'], axis=1)

# Getting samples from the first stage only
ind = np.logical_and(df.segStageI_index > 0, df.segStageI_index <= 1) 
df = df.loc[ind, :]

# Encoding the pH colums
df['pH'] = (df.pH <= 7.05).astype(int).ravel()

# Dropping unused columns:
cat_features = ['segStart_samp', 'segEnd_samp', 'segIndex', 'segStage', 'segStageI_index', 'segStageII_index']
df = df.drop(cat_features, axis=1)

# Dropping NA samples
df = df.dropna()

# Feature matrix 
y = df['pH']
X = df.drop(['pH'], axis=1)

df.head()
# Out:
#     pH        mean        std  median        mad  skewness  kurtosis  \
# 13   0  136.043207  34.244851  144.25  30.625562 -0.299440  1.683251
# 46   0  147.072604  12.863330  145.75  10.407536  0.036986  2.707744
# 64   0  129.858446  16.675711  134.00  12.348971 -0.756702  4.220946
# 78   0  117.748872  19.359356  119.25  12.142754 -0.357331  7.590784
# 90   0  140.781758   7.376388  141.50   5.412613 -1.310544  9.277056
#
#       bslnMean    bslnSD  stressRatio    ...        MF_c1     MF_c2     MF_c3  \
# 13  172.141798  0.458852     0.802292    ...     1.541740 -0.320374 -0.072248
# 46  150.480682  2.446956     0.332500    ...     1.526265 -0.002046  0.006373
# 64  137.205903  1.195552     0.287500    ...     1.513655 -0.025695 -0.036561
# 78  121.913976  1.199712     0.352917    ...     1.599210 -0.260384 -0.234299
# 90  144.036013  0.720803     0.129167    ...     1.415286 -0.116083 -0.014288
#
#        MF_c4      H310       H29  MF_c1_29  MF_c2_29  MF_c3_29  MF_c4_29
# 13  0.443586  0.251573  0.322433  1.561143 -0.237683 -0.072733  0.186351
# 46 -0.061292  0.476296  0.525474  1.561249  0.009067 -0.000521 -0.062645
# 64 -0.142221  0.432595  0.460897  1.525905 -0.010476 -0.034858 -0.138176
# 78 -0.055279  0.189094  0.298341  1.623602 -0.222504 -0.128656 -0.089185
# 90 -0.030838  0.254531  0.358241  1.486842 -0.096960  0.032126 -0.189776
#
# [5 rows x 42 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

clf = LogisticRegression()
scaler = StandardScaler()

steps = [
    ('standard_scaler', scaler),
    ('clf', clf),
]

# %%
pipe = Pipeline(steps)

# %%
pipe
# Out:
# Pipeline(memory=None,
#      steps=[('standard_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('clf', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False))])

# %%
# Out:
# 0.9809502465262214
